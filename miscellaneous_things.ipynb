# %%
# Inheritance → tight coupling

# Composition → flexible, replaceable behavior

class Button(WindowsRenderer):
    pass

class Button:
    def __init__(self, renderer):
        self.renderer = renderer
